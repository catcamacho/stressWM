# %% [markdown]
# # dMRI Preprocessing
#
# This note book processes multiband diffusion weighted imaging for tensor-based analyses

# %%
from nipype.pipeline.engine import Workflow, Node, JoinNode, MapNode
from nipype.interfaces.utility import IdentityInterface, Function
from nipype.interfaces.io import SelectFiles, DataSink, DataGrabber
from nipype.interfaces.fsl import BET, MeanImage, ApplyTOPUP, TOPUP, Merge,ExtractROI
from nipype.interfaces.ants import RegistrationSynQuick, ApplyTransforms

# MATLAB setup - Specify path to current SPM and the MATLAB's default mode
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('~/spm12/toolbox')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# FSL set up- change default file output type
from nipype.interfaces.fsl import FSLCommand
FSLCommand.set_default_output_type('NIFTI_GZ')

# Study-specific variables
project_home = '/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc'
output_dir = project_home + '/proc/preprocessing'
workflow_dir = project_home + '/workflows'
raw_dir = '/data/perlman/moochie/study_data/EmoGrow/MRI_data'
phase_encoding_file = project_home + '/misc/acq_params.txt'

subjects_list = open(project_home + '/misc/emogrow_subjects.txt').read().splitlines()
#subjects_list=['085','120']

# FreeSurfer set up - change SUBJECTS_DIR 
fs_dir = '/moochie/Cat/Aggregate_anats/subjects_dir'
# FSCommand.set_default_subjects_dir(fs_dir)
# Out:
# 210516-15:48:25,633 nipype.utils WARNING:
# 	 Could not check for version updates:
# 500 Server Error: Internal Server Error for url: https://rig.mit.edu/et/projects/nipy/nipype

# %%
### Universal nodes

# get subjects list
infosource = Node(IdentityInterface(fields=['subjid']),
                  name='infosource')
infosource.iterables = [('subjid', subjects_list)]

# Sink data of interest
substitutions = [('_subjid_', '')] #output file name substitutions
datasink = Node(DataSink(base_directory = output_dir,
                        container = output_dir,
                        substitutions = substitutions), 
                name='datasink')

# %% [markdown]
# ## Unwarping workflow
#
# This workflow includes both unwarping and eddy correction.

# %%
# select dMRI data
dmri_template = {'dmri_pe0': raw_dir + '/sub-{subjid}/dwi/sub-{subjid}_dir98_AP.nii.gz',
                 'bval':raw_dir + '/sub-{subjid}/dwi/sub-{subjid}_dir98_AP.bval',
                 'bvec':raw_dir + '/sub-{subjid}/dwi/sub-{subjid}_dir98_AP.bvec'}
selectdmri = Node(SelectFiles(dmri_template), name='selectdmri')

pes_template={'pes':raw_dir + '/sub-{subjid}/dwi/sub-{subjid}_dir98_{pe}.nii.gz'}
selectpes = Node(SelectFiles(pes_template),name='selectpes')
selectpes.iterables=('pe',['AP','PA'])

# include only the first volume of each PE volume
trim_pes = Node(ExtractROI(t_min=0,t_size=1,roi_file='pe_trimmed.nii.gz'),name='trim_pes')

# merge to 1 file for topup to calculate the fieldcoef
merge_pes = JoinNode(Merge(dimension='t',
                           merged_file='merged_pes.nii.gz'),
                     name='merge_pes', joinsource='selectpes', joinfield='in_files')

# actually do the unwarping
topup = Node(TOPUP(encoding_file=phase_encoding_file), name='topup')

apply_topup = Node(ApplyTOPUP(in_index=[1], encoding_file=phase_encoding_file,
                              method='jac', out_corrected='dmri_unwarped.nii.gz'),
                   name='apply_topup')

# average dMRI so we can make a mask
avg_dmri = Node(MeanImage(), name='avg_dmri')

# create a dMRI space brain mask using BET
make_mask = Node(BET(mask=True), name='make_mask')

# %%
prepreprocflow = Workflow(name='prepreprocflow')
prepreprocflow.connect([(infosource,selectdmri, [('subjid','subjid')]),
                        (infosource, selectpes, [('subjid','subjid')]),
                        (selectpes, trim_pes, [('pes','in_file')]),
                        (trim_pes, merge_pes,[('roi_file','in_files')]),
                        (merge_pes, topup, [('merged_file','in_file')]),
                        (topup, apply_topup, [('out_fieldcoef','in_topup_fieldcoef'), 
                                              ('out_movpar','in_topup_movpar')]),
                        (selectdmri, apply_topup, [('dmri_pe0','in_files')]),
                        (apply_topup, avg_dmri, [('out_corrected','in_file')]),
                        (avg_dmri, make_mask, [('out_file','in_file')]),
                        (make_mask, datasink, [('mask_file','in_mask')]),
                        (apply_topup, datasink, [('out_corrected','unwarped_niftis')])
                       ])

prepreprocflow.base_dir = workflow_dir
#prepreprocflow.write_graph(graph2use='flat')
prepreprocflow.run('MultiProc', plugin_args={'n_procs': 4, 'memory_gb':10})
# Out:
# 200729-20:09:47,852 nipype.workflow INFO:
# 	 Workflow prepreprocflow settings: ['check', 'execution', 'logging', 'monitoring']
# 200729-20:09:47,879 nipype.workflow INFO:
# 	 Running in parallel.
# 200729-20:09:47,882 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 200729-20:09:47,938 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.selectpes" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/_pe_PA/selectpes".
# 200729-20:09:47,940 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.selectpes" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/_pe_AP/selectpes".
# 200729-20:09:47,941 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.selectdmri" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/selectdmri".
# 200729-20:09:47,942 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.selectpes" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/_pe_PA/selectpes".
# 200729-20:09:47,953 nipype.workflow INFO:
# 	 [Node] Running "selectpes" ("nipype.interfaces.io.SelectFiles")
# 200729-20:09:47,953 nipype.workflow INFO:
# 	 [Node] Running "selectpes" ("nipype.interfaces.io.SelectFiles")
# 200729-20:09:47,955 nipype.workflow INFO:
# 	 [Node] Running "selectpes" ("nipype.interfaces.io.SelectFiles")
# 200729-20:09:47,955 nipype.workflow INFO:
# 	 [Node] Running "selectdmri" ("nipype.interfaces.io.SelectFiles")
# 200729-20:09:47,961 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.selectpes".
# 200729-20:09:47,962 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.selectpes".
# 200729-20:09:47,964 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.selectdmri".
# 200729-20:09:48,22 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.selectpes".
# 200729-20:09:49,886 nipype.workflow INFO:
# 	 [Job 0] Completed (prepreprocflow.selectpes).
# 200729-20:09:49,890 nipype.workflow INFO:
# 	 [Job 2] Completed (prepreprocflow.selectpes).
# 200729-20:09:49,893 nipype.workflow INFO:
# 	 [Job 6] Completed (prepreprocflow.selectdmri).
# 200729-20:09:49,895 nipype.workflow INFO:
# 	 [Job 11] Completed (prepreprocflow.selectpes).
# 200729-20:09:49,896 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 200729-20:09:49,940 nipype.workflow INFO:
# 	 [Job 1] Cached (prepreprocflow.trim_pes).
# 200729-20:09:49,944 nipype.workflow INFO:
# 	 [Job 3] Cached (prepreprocflow.trim_pes).
# 200729-20:09:49,947 nipype.workflow INFO:
# 	 [Job 12] Cached (prepreprocflow.trim_pes).
# 200729-20:09:49,950 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.selectpes" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/_pe_AP/selectpes".
# 200729-20:09:49,959 nipype.workflow INFO:
# 	 [Node] Running "selectpes" ("nipype.interfaces.io.SelectFiles")
# 200729-20:09:49,965 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.selectpes".
# 200729-20:09:51,887 nipype.workflow INFO:
# 	 [Job 13] Completed (prepreprocflow.selectpes).
# 200729-20:09:51,892 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 200729-20:09:51,930 nipype.workflow INFO:
# 	 [Job 4] Cached (prepreprocflow.merge_pes).
# 200729-20:09:51,934 nipype.workflow INFO:
# 	 [Job 14] Cached (prepreprocflow.trim_pes).
# 200729-20:09:51,938 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.selectdmri" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/selectdmri".
# 200729-20:09:51,947 nipype.workflow INFO:
# 	 [Node] Running "selectdmri" ("nipype.interfaces.io.SelectFiles")
# 200729-20:09:51,954 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.selectdmri".
# 200729-20:09:53,889 nipype.workflow INFO:
# 	 [Job 17] Completed (prepreprocflow.selectdmri).
# 200729-20:09:53,894 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 200729-20:09:53,934 nipype.workflow INFO:
# 	 [Job 15] Cached (prepreprocflow.merge_pes).
# 200729-20:09:53,934 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.topup" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/topup".
# 200729-20:09:53,948 nipype.workflow INFO:
# 	 [Node] Running "topup" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/misc/acq_params.txt --imain=/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/merge_pes/merged_pes.nii.gz --out=merged_pes_base --iout=merged_pes_corrected.nii.gz --fout=merged_pes_field.nii.gz --jacout=jac --logout=merged_pes_topup.log --rbmout=xfm --dfout=warpfield
# 200729-20:09:55,893 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 3/4.
#                      Currently running:
#                        * prepreprocflow.topup
# 200729-20:09:55,935 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.topup" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/topup".
# 200729-20:09:55,948 nipype.workflow INFO:
# 	 [Node] Running "topup" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/misc/acq_params.txt --imain=/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/merge_pes/merged_pes.nii.gz --out=merged_pes_base --iout=merged_pes_corrected.nii.gz --fout=merged_pes_field.nii.gz --jacout=jac --logout=merged_pes_topup.log --rbmout=xfm --dfout=warpfield
# 200729-20:09:57,895 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 9.60/10.00, Free processors: 2/4.
#                      Currently running:
#                        * prepreprocflow.topup
#                        * prepreprocflow.topup
# 200729-20:23:04,37 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.topup".
# 200729-20:23:04,732 nipype.workflow INFO:
# 	 [Job 16] Completed (prepreprocflow.topup).
# 200729-20:23:04,736 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 3/4.
#                      Currently running:
#                        * prepreprocflow.topup
# 200729-20:23:04,782 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.apply_topup" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/apply_topup".
# 200729-20:23:04,794 nipype.workflow INFO:
# 	 [Node] Running "apply_topup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/misc/acq_params.txt --imain=/data/perlman/moochie/study_data/EmoGrow/MRI_data/sub-085/dwi/sub-085_dir98_AP.nii.gz --inindex=1 --topup=/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/apply_topup/merged_pes_base --method=jac --out=dmri_unwarped.nii.gz
# 200729-20:23:05,143 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.topup".
# 200729-20:23:06,735 nipype.workflow INFO:
# 	 [Job 5] Completed (prepreprocflow.topup).
# 200729-20:23:06,738 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 3/4.
#                      Currently running:
#                        * prepreprocflow.apply_topup
# 200729-20:23:06,784 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.apply_topup" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/apply_topup".
# 200729-20:23:06,799 nipype.workflow INFO:
# 	 [Node] Running "apply_topup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/misc/acq_params.txt --imain=/data/perlman/moochie/study_data/EmoGrow/MRI_data/sub-120/dwi/sub-120_dir98_AP.nii.gz --inindex=1 --topup=/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/apply_topup/merged_pes_base --method=jac --out=dmri_unwarped.nii.gz
# 200729-20:23:08,737 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 9.60/10.00, Free processors: 2/4.
#                      Currently running:
#                        * prepreprocflow.apply_topup
#                        * prepreprocflow.apply_topup
# 200729-20:25:22,431 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.apply_topup".
# 200729-20:25:22,880 nipype.workflow INFO:
# 	 [Job 18] Completed (prepreprocflow.apply_topup).
# 200729-20:25:22,883 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 3/4.
#                      Currently running:
#                        * prepreprocflow.apply_topup
# 200729-20:25:22,929 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.avg_dmri" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/avg_dmri".
# 200729-20:25:22,939 nipype.workflow INFO:
# 	 [Node] Running "avg_dmri" ("nipype.interfaces.fsl.maths.MeanImage"), a CommandLine Interface with command:
# fslmaths /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/apply_topup/dmri_unwarped.nii.gz -Tmean /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/avg_dmri/dmri_unwarped_mean.nii.gz
# 200729-20:25:24,884 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 9.60/10.00, Free processors: 2/4.
#                      Currently running:
#                        * prepreprocflow.avg_dmri
#                        * prepreprocflow.apply_topup
# 200729-20:25:25,620 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.apply_topup".
# 200729-20:25:26,885 nipype.workflow INFO:
# 	 [Job 7] Completed (prepreprocflow.apply_topup).
# 200729-20:25:26,890 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 3/4.
#                      Currently running:
#                        * prepreprocflow.avg_dmri
# 200729-20:25:26,937 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.avg_dmri" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/avg_dmri".
# 200729-20:25:26,945 nipype.workflow INFO:
# 	 [Node] Running "avg_dmri" ("nipype.interfaces.fsl.maths.MeanImage"), a CommandLine Interface with command:
# fslmaths /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/apply_topup/dmri_unwarped.nii.gz -Tmean /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/avg_dmri/dmri_unwarped_mean.nii.gz
# 200729-20:25:28,889 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 9.60/10.00, Free processors: 2/4.
#                      Currently running:
#                        * prepreprocflow.avg_dmri
#                        * prepreprocflow.avg_dmri
# 200729-20:25:30,333 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.avg_dmri".
# 200729-20:25:30,890 nipype.workflow INFO:
# 	 [Job 19] Completed (prepreprocflow.avg_dmri).
# 200729-20:25:30,894 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 3/4.
#                      Currently running:
#                        * prepreprocflow.avg_dmri
# 200729-20:25:30,942 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.make_mask" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/make_mask".
# 200729-20:25:30,952 nipype.workflow INFO:
# 	 [Node] Running "make_mask" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/avg_dmri/dmri_unwarped_mean.nii.gz /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/make_mask/dmri_unwarped_mean_brain.nii.gz -m
# 200729-20:25:32,407 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.make_mask".
# 200729-20:25:32,892 nipype.workflow INFO:
# 	 [Job 20] Completed (prepreprocflow.make_mask).
# 200729-20:25:32,896 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 3/4.
#                      Currently running:
#                        * prepreprocflow.avg_dmri
# 200729-20:25:32,943 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.datasink" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_085/datasink".
# 200729-20:25:32,954 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200729-20:25:32,956 nipype.interface INFO:
# 	 sub: /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/proc/preprocessing/unwarped_niftis/_subjid_085/dmri_unwarped.nii.gz -> /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/proc/preprocessing/unwarped_niftis/085/dmri_unwarped.nii.gz
# 200729-20:25:32,958 nipype.interface INFO:
# 	 sub: /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/proc/preprocessing/in_mask/_subjid_085/dmri_unwarped_mean_brain_mask.nii.gz -> /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/proc/preprocessing/in_mask/085/dmri_unwarped_mean_brain_mask.nii.gz
# 200729-20:25:32,965 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.datasink".
# 200729-20:25:34,382 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.avg_dmri".
# 200729-20:25:34,894 nipype.workflow INFO:
# 	 [Job 8] Completed (prepreprocflow.avg_dmri).
# 200729-20:25:34,897 nipype.workflow INFO:
# 	 [Job 21] Completed (prepreprocflow.datasink).
# 200729-20:25:34,900 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 200729-20:25:34,946 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.make_mask" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/make_mask".
# 200729-20:25:34,955 nipype.workflow INFO:
# 	 [Node] Running "make_mask" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/avg_dmri/dmri_unwarped_mean.nii.gz /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/make_mask/dmri_unwarped_mean_brain.nii.gz -m
# 200729-20:25:36,432 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.make_mask".
# 200729-20:25:36,896 nipype.workflow INFO:
# 	 [Job 9] Completed (prepreprocflow.make_mask).
# 200729-20:25:36,899 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 200729-20:25:36,946 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.datasink" in "/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_120/datasink".
# 200729-20:25:36,956 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200729-20:25:36,958 nipype.interface INFO:
# 	 sub: /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/proc/preprocessing/unwarped_niftis/_subjid_120/dmri_unwarped.nii.gz -> /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/proc/preprocessing/unwarped_niftis/120/dmri_unwarped.nii.gz
# 200729-20:25:36,960 nipype.interface INFO:
# 	 sub: /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/proc/preprocessing/in_mask/_subjid_120/dmri_unwarped_mean_brain_mask.nii.gz -> /data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/proc/preprocessing/in_mask/120/dmri_unwarped_mean_brain_mask.nii.gz
# 200729-20:25:36,967 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.datasink".
# 200729-20:25:38,898 nipype.workflow INFO:
# 	 [Job 10] Completed (prepreprocflow.datasink).
# 200729-20:25:38,902 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.

# %% [markdown]
# ## Preprocessing for subjects without both encoding directions
# This workflow makes group a average fieldmap as done in Laumann et al. 2015

# %%
def make3DTemplate(subject_vols, num_proc, output_prefix):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    from os.path import abspath, split
    from os import getcwd
    from shutil import copyfile
    import subprocess 

    curr_dir = getcwd()

    #copy data into current directory
    for T in range(0,len(subject_vols)):
        [dirname,filename] = split(subject_vols[T])
        copyfile(subject_vols[T],curr_dir + '/' + str(T)+'_'+filename)

    # -c flag is control for local computing (2= use localhost; required for -j flag)
    # -j flag is for number of processors allowed

    subprocess.check_call(['antsMultivariateTemplateConstruction2.sh','-d','3','-o', 
                           output_prefix,'-r','1','-c','2','-n','0','-j', str(num_proc), '*.nii.gz'], shell=True)
    
    sample_template = abspath(output_prefix + 'template0.nii.gz')
    
    return(sample_template)

# %%
# sort IDs with good and bad fieldmaps
subs_corr_fmap = ['1000', '1001', '1008', '1011', '1016', '1017', '1027', '1031',
                  '1034', '1036', '1040', '1045', '1047', '1048', '1052', '1053'] #used to make group mean fieldmap
subs_to_unwarp = ['004', '005', '011', '012', '023', '032', '044', '049', '053', 
                  '055', '057', '060', '062', '084', '092', '093', '123', '130']
# get subjects list
infosource = Node(IdentityInterface(fields=['subjid']),
                  name='infosource')
infosource.iterables = [('subjid', subs_to_unwarp)]

# select good pes
pe_template={'pe': '/data/perlman/moochie/user_data/CamachoCat/ChEC/dmri_proc/misc/%s_pe_template0.nii.gz'}
grab_pe_data = Node(DataGrabber(field_template=pe_template, 
                                sort_filelist=True,
                                base_directory=raw_dir, 
                                template='/data/perlman/moochie/user_data/CamachoCat/ChEC/dmri_proc/misc/%s_pe_template0.nii.gz', 
                                infields=['dir'], 
                                template_args={'pe':[['dir']]}), 
                    name='grab_pe_data')
grab_pe_data.iterables=('dir',['AP','PA'])

# grab just first B0 volume for registration
trim_b0 = Node(ExtractROI(t_min=0, t_size=1), name='trim_b0')

# merge to 1 file for topup to calculate the fieldcoef
merge_pes = JoinNode(Merge(dimension='t',
                           merged_file='merged_pes.nii.gz'),
                     name='merge_pes', joinsource='grab_pe_data', joinfield='in_files')

#register template to subject data
register2subject = Node(RegistrationSynQuick(dimension=3,
                                             transform_type='a'), name='register2subject')

# %%
groupunwarp = Workflow(name='groupunwarp')
groupunwarp.connect([(infosource,selectdmri, [('subjid','subjid')]),
                     (grab_pe_data, register2subject,[('pe','moving_image')]),
                     (selectdmri, trim_b0, [('dmri_pe0','in_file')]),
                     (trim_b0, register2subject, [('roi_file','fixed_image')]),
                     (register2subject, merge_pes, [('warped_image','in_files')]),
                     (merge_pes, topup, [('merged_file','in_file')]),
                     (topup, apply_topup, [('out_fieldcoef','in_topup_fieldcoef'), 
                                           ('out_movpar','in_topup_movpar')]),
                     (selectdmri, apply_topup, [('dmri_pe0','in_files')]),
                     (apply_topup, avg_dmri, [('out_corrected','in_file')]),
                     (avg_dmri, make_mask, [('out_file','in_file')]),
                     (make_mask, datasink, [('mask_file','in_mask')]),
                     (apply_topup, datasink, [('out_corrected','unwarped_niftis')])
                    ])

groupunwarp.base_dir = workflow_dir
#groupunwarp.write_graph(graph2use='flat')
groupunwarp.run('MultiProc', plugin_args={'n_procs': 4, 'memory_gb':10})

# %% [markdown]
# ### Make b-tables and generate .src file

# %%
import numpy as np
from os.path import isdir

analysis_home = '/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/proc/preprocessing'
nifti_home = analysis_home + '/unwarped_niftis'
nifti_raw = '/data/perlman/moochie/study_data/EmoGrow/MRI_data'

# get subjects list
infosource = Node(IdentityInterface(fields=['subjid']),
                  name='infosource')
infosource.iterables = [('subjid', subjects_list)]

for sub in subjects_list:
    if isdir(nifti_home + '/{sub}'.format(sub=sub)):
        bvals = np.loadtxt(nifti_raw + '/sub-{sub}/dwi/sub-{sub}_dir98_AP.bval'.format(sub=sub))
        bvecs = np.loadtxt(nifti_raw + '/sub-{sub}/dwi/sub-{sub}_dir98_AP.bvec'.format(sub=sub))
        bvals = np.expand_dims(bvals,axis=1)
        bvecs = np.transpose(bvecs)
        btable = np.hstack((bvals,bvecs))
        np.savetxt(nifti_home + '/{sub}/sub-{sub}_btable.txt'.format(sub=sub),btable)

# %%
from subprocess import call
from os import mkdir

for sub in subjects_list:
    if isdir(nifti_home + '/{sub}'.format(sub=sub)):
        #mkdir(analysis_home + '/dsi_studio/{sub}'.format(sub=sub))
        nifti_path = nifti_home + '/{sub}/dmri_unwarped.nii.gz'.format(sub=sub)
        btable_path = nifti_home + '/{sub}/sub-{sub}_btable.txt'.format(sub=sub)
        src_path = analysis_home + '/dsi_studio/{sub}/sub-{sub}_dMRI_98dir_unwarped.src'.format(sub=sub)

        call(['dsi_studio','--action=src','--source='+ nifti_path,'--b_table=' + btable_path, '--output='+src_path])

# %% [markdown]
# ### Generate connectograms from fiber files

# %%
from os import path, chdir
from glob import glob
from subprocess import call

#subjects_list=['1001','1006','1007','1008','1011','1012','1015','1016','1023','1027','1031','1032','1034','1040','1045','1053']
#fib_home = '/data/perlman/moochie/user_data/CamachoCat/ChEC/dmri_proc/proc/preprocessing/dsi_studio'

subjects_list=['0002','0003','0006','0009','0011','0012','0013','0014','0015','0017','0018','0019','0023','0025',
               '0026','0027','0029','0030','0031','0032','0035','0036','0037','0038','0039','0040','0041','0042',
               '0044','0047','0049','0050','0051','0053','0054','0055','0056','0057','0059','0060','0061','0063',
               '0064','0065','0067','0070','0071','0072','0073','0074','0079','0080','0083','0085','0086','0089',
               '0090','0093','0097','0099','0100','0102','0103','0107','0109','0110','0112','0113','0116','0117',
               '0118','0119','0120','0122','0124','0125','0126','0127','0129','0140']
fib_home = '/data/perlman/moochie/user_data/CamachoCat/EmoGrow/dMRI_proc/proc/preprocessing/dsi_studio'

for sub in subjects_list:
    fib_file = glob(fib_home + '/{sub}/*fib.gz'.format(sub=sub))
    chdir(fib_home + '/{0}'.format(sub))
    call(['dsi_studio','--action=trk','--source='+fib_file[0],'--parameter_id=ba3F9A99193FF304353Fba3FcbF041b9643A08601dcaCDCC4C3Ec', 
          '--connectivity=MMP_subcort', '--connectivity_type=pass', '--connectivity_value=qa', '--otsu_threshold=0.6'])
